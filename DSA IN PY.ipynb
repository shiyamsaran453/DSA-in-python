# %% [markdown]
# # STACK IMPLEMENTATION THROUGH LIST

# %%
#inserting the data
stack=[]
stack.append("shiyam")
stack.append("saran")
stack.append("learn with smss")
print(stack)
# Out:
# ['shiyam', 'saran', 'learn with smss']

# %%
#removeing the data
stack.pop() #stack follows lifo 
print(stack)
# Out:
# ['shiyam', 'saran']

# %% [markdown]
# # STACK IMPLEMENTATION THROUGH DEQUE

# %%
#REQUIRED LIBRARY COLLECTION AND import DEQUE
from collections import deque
stack=deque()
stack.append("shiyam")
stack.append("saran")
stack.append("sachin")
print(stack)
# Out:
# deque(['shiyam', 'saran', 'sachin'])

# %%
#removeing the data
stack.pop()
print(stack)
# Out:
# deque(['shiyam', 'saran'])

# %% [markdown]
# # advantages of deque
# 1.faster than list
# 2.time complexity 0(1) but in list o(n)

# %% [markdown]
# # STACK IMPLEMENTATION THROUGH queue

# %% [markdown]
# # advantages
# it has some additional functions than deque,
# put func is used to insert the element,
# get func isused to remove the element.

# %%
#REQUIRED LIBRARY queue AND import LifoQueue
from queue import LifoQueue
stack=LifoQueue(maxsize=4)#maxsize is used to set the stck size
stack.put("shiyam")
stack.put("saran")
stack.put("sachin")
print(stack.qsize())#size of stack
print(stack.full())#if the stack is full return true
print(stack.get())# to remove element
# Out:
# 3
# False
# sachin

# %% [markdown]
# # Disadvantages of queue :
# it not flexible because it has a single opening to add or remove element

# %% [markdown]
# # QUEUE IMPLEMENTATION

# %%
import cv2
import matplotlib.pyplot as plt
a=cv2.imread("C:/Users/shiya/OneDrive/Pictures/Screenshots/QUEUE.jpg")
plt.imshow(a)

# %%
class Queue:
    def __init__(self):
        self.queue = [None]
    def enqueue(self, data):
        self.queue.append(data)
    def peeklast(self):
        if len(self.queue) > 0:
            return self.queue[-1]
        else:
            return None
    def peekfirst(self):
        if len(self.queue) > 0:
            return self.queue[0]
        else:
            return None
    def dequeue(self):
        if len(self.queue) > 0:
            return self.queue.pop(0)
        else:
            return None
    def size(self):
        return len(self.queue)
    def display(self):
        print(self.queue)
x = Queue()

# %%
x.enqueue(5)
x.enqueue(10)
x.enqueue(0)
x.enqueue(15)
x.enqueue(20)

# %% [markdown]
# # circular queue

# %%
cq=cv2.imread("C:/Users/shiya/OneDrive/Pictures/Screenshots/cq.png")
plt.imshow(cq)

# %%
class q:
    def __init__(s,cap):
        s.cap=cap
        s.q=[]*s.cap
        s.f=s.r=-1
    def is_empty(s):
        if s.f==-1:
            return True
        else:
            return False
    def is_full(s):
        return (s.r+1)%s.cap==s.f
    def enqueue(s,data):
        if s.is_full():
            return ("queue is full")
        elif s.is_empty():
            s.f=s.r==0
            s.r=data
            s.q.append(s.r)
            return s.q
        else:
            s.r=(s.r+1)%s.cap
            s.r=data
            s.q.append(s.r)
            return s.q
    def dequeue(s):
        if s.is_empty():
            return "q is empty"
        
        else:
            rv=s.q.pop(s.f)
            if len(s.q)==0:
                s.f=s.r=-1
            return 
            
        
x=q(5)

# %%
x.enqueue(5)
x.enqueue(2)
x.enqueue(6)
x.enqueue(0)
x.enqueue(5)
x.enqueue(9)
# Out:
# [5, 2, 6, 0, 5, 9]

# %% [markdown]
# # priority queue using heap lib

# %%
pri=cv2.imread("C:/Users/shiya/OneDrive/Pictures/Screenshots/pri.png")
plt.imshow(pri)

# %%
import heapq

class PriorityQueue:
    def __init__(self):
        self._queue = []
        self._index = 0

    def push(self, item, priority):
        heapq.heappush(self._queue, (priority, self._index, item))
        self._index += 1
        return self._queue

    def pop(self):
        return heapq.heappop(self._queue)[-1]
        print(self._queue)
    def is_empty(self):
        return len(self._queue) == 0

# Example usage:
pq = PriorityQueue()
pq.push('task1', 5)
pq.push('task2', 1)
pq.push('task3', 3)

#while not pq.is_empty():
#print(pq.pop())  # Output: task2, task3, task1
# Out:
# [(1, 1, 'task2'), (5, 0, 'task1'), (3, 2, 'task3')]

# %%
(pq.pop())  # Output: task2, task3, task1
# Out:
# 'task2'

# %% [markdown]
# # using list

# %% [raw]
# pq=[]
# pq.append((2,"p1"))#using tuple method
# pq.append((4,"p2"))
# pq.append((1,"p3"))
# print(pq)
# pq.sort()
# print(pq.pop(0))

# %%
print(pq.pop(0))
# Out:
# (2, 'p1')

# %% [markdown]
# # deque(double ended queue)

# %% [raw]
# Deque or Double Ended Queue is a type of queue in which insertion and removal of elements can either be performed from the front or the rear. Thus, it does not follow FIFO rule (First In First Out).

# %%
im=cv2.imread("C:/Users/shiya/OneDrive/Pictures/Screenshots/de.png")
plt.imshow(im)

# %%
class Deque:
    def __init__(self):
        self.items = []

    def is_empty(self):
        return len(self.items) == 0

    def add_front(self, item):
        self.items.insert(0, item)

    def add_rear(self, item):
        self.items.append(item)

    def remove_front(self):
        if self.is_empty():
            return "Deque is empty"
        return self.items.pop(0)

    def remove_rear(self):
        if self.is_empty():
            return "Deque is empty"
        return self.items.pop()

    def display(self):
        print(self.items)


# Example usage:
deque = Deque()
deque.add_front(1)
deque.add_front(2)
deque.add_rear(3)
deque.add_rear(4)
deque.display()  # Output: [2, 1, 3, 4]
print(deque.remove_front())  # Output: 2
print(deque.remove_rear())   # Output: 4
deque.display()  # Output: [1, 3]
# Out:
# [2, 1, 3, 4]
# 2
# 4
# [1, 3]
